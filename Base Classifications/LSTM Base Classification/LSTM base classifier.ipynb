# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import pathlib

# Random seed for reproducability
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

from keras.models import Sequential
from keras.layers import LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

import json
# Loading dataset splits from JSON into correct paths for the model
with open(r"C:\Users\wegar\Deadlift Classification v2\splits\v2 split.json", "r") as f:
    splits = json.load(f) # Loads the dictionary of train, test, val clip distribution (only names, not paths)

video_folder = pathlib.Path(r"C:\Users\wegar\Deadlift Classification v2\KPS arrays")

subset_paths = {
    split: [video_folder / f"{fname}.npy" for fname in splits[split]] for split in ["train", "val", "test"]
}

# %%
def interpolate_kps(kps, target_frames=200):
    frames, features = kps.shape  # features = 51

    interpolated = np.zeros((target_frames, features), dtype=np.float32)
    for i in range(features):
        interpolated[:, i] = np.interp(
            np.linspace(0, frames - 1, target_frames),
            np.arange(frames),
            kps[:, i]
        )
    return interpolated


unique_labels = set(fname.split("_")[0] for split in splits for fname in splits[split])


label_dict = {label: idx for idx, label in enumerate(sorted(unique_labels))}

def load_data(split):
    X = []
    for array in subset_paths[split]:
        kps = np.load(array).reshape(-1, 51)
        kps_interp = interpolate_kps(kps, target_frames=200)
        X.append(kps_interp)

    y = [label_dict[fname.split("_")[0]] for fname in splits[split]]
    y = to_categorical(y, num_classes=len(label_dict)) # One-hot encoding

    return np.array(X), np.array(y)

X_train, y_train = load_data('train')
X_val, y_val = load_data('val')
X_test, y_test = load_data('test')

# %%
idx_to_label = {v: k for k, v in label_dict.items()}
print(idx_to_label)
# Out:
# {0: 'R', 1: 'S', 2: 'conv'}

# %%
from sklearn.utils import shuffle

X_train, y_train = shuffle(X_train, y_train, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, ReLU, Dropout, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau



optimizer = Adam(learning_rate=1e-4)
verbose, epochs, batch_size = 1, 1000, 32
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train.shape[1]

model = Sequential([
    LSTM(256, return_sequences=True, input_shape=(n_timesteps, n_features)),
    LSTM(128),
    Dropout(0.5),
    Dense(128, activation="relu"),
    Dense(n_outputs, activation='softmax')
])

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(
    monitor='val_loss',      
    patience=20,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.8, patience=10, min_lr=5e-6
)


history = model.fit(X_train, y_train, 
                    epochs=epochs, 
                    validation_data = (X_val, y_val),
                    batch_size=batch_size, 
                    callbacks=[early_stop, reduce_lr],
                    verbose=verbose)
# Out:
# Epoch 1/1000
# 25/25 [==============================] - 6s 113ms/step - loss: 1.0891 - accuracy: 0.3961 - val_loss: 1.0629 - val_accuracy: 0.6364 - lr: 1.0000e-04
# Epoch 2/1000
# 25/25 [==============================] - 2s 72ms/step - loss: 1.0540 - accuracy: 0.4662 - val_loss: 1.0291 - val_accuracy: 0.3831 - lr: 1.0000e-04
# Epoch 3/1000
# 25/25 [==============================] - 2s 81ms/step - loss: 0.9516 - accuracy: 0.5558 - val_loss: 0.8272 - val_accuracy: 0.6883 - lr: 1.0000e-04
# Epoch 4/1000
# 25/25 [==============================] - 2s 73ms/step - loss: 0.7182 - accuracy: 0.6896 - val_loss: 0.9846 - val_accuracy: 0.5649 - lr: 1.0000e-04
# Epoch 5/1000
# 25/25 [==============================] - 2s 72ms/step - loss: 0.8429 - accuracy: 0.6065 - val_loss: 0.6969 - val_accuracy: 0.7078 - lr: 1.0000e-04
# Epoch 6/1000
# 25/25 [==============================] - 2s 70ms/step - loss: 0.6149 - accuracy: 0.7584 - val_loss: 0.5808 - val_accuracy: 0.7468 - lr: 1.0000e-04
# Epoch 7/1000
# 25/25 [==============================] - 2s 66ms/step - loss: 0.5119 - accuracy: 0.7805 - val_loss: 0.7696 - val_accuracy: 0.6169 - lr: 1.0000e-04
# Epoch 8/1000
# 25/25 [==============================] - 2s 67ms/step - loss: 0.6334 - accuracy: 0.6792 - val_loss: 0.5267 - val_accuracy: 0.7922 - lr: 1.0000e-04
# Epoch 9/1000
# 25/25 [==============================] - 2s 73ms/step - loss: 0.4941 - accuracy: 0.7896 - val_loss: 0.5181 - val_accuracy: 0.7857 - lr: 1.0000e-04
# Epoch 10/1000
# 25/25 [==============================] - 2s 70ms/step - loss: 0.4208 - accuracy: 0.8299 - val_loss: 0.5646 - val_accuracy: 0.6883 - lr: 1.0000e-04
# Epoch 11/1000
# 25/25 [==============================] - 2s 76ms/step - loss: 0.3769 - accuracy: 0.8584 - val_loss: 0.4465 - val_accuracy: 0.8506 - lr: 1.0000e-04
# Epoch 12/1000
# 25/25 [==============================] - 2s 73ms/step - loss: 0.3470 - accuracy: 0.8649 - val_loss: 0.6058 - val_accuracy: 0.6948 - lr: 1.0000e-04
# Epoch 13/1000
# 25/25 [==============================] - 2s 67ms/step - loss: 0.3163 - accuracy: 0.8896 - val_loss: 0.4663 - val_accuracy: 0.8377 - lr: 1.0000e-04
# Epoch 14/1000
# 25/25 [==============================] - 2s 68ms/step - loss: 0.3347 - accuracy: 0.8844 - val_loss: 0.3744 - val_accuracy: 0.8766 - lr: 1.0000e-04
# Epoch 15/1000
# 25/25 [==============================] - 2s 69ms/step - loss: 0.3297 - accuracy: 0.8675 - val_loss: 0.4798 - val_accuracy: 0.7922 - lr: 1.0000e-04
# Epoch 16/1000
# 25/25 [==============================] - 2s 69ms/step - loss: 0.2931 - accuracy: 0.9039 - val_loss: 0.3305 - val_accuracy: 0.8766 - lr: 1.0000e-04
# Epoch 17/1000
# 25/25 [==============================] - 2s 69ms/step - loss: 0.2351 - accuracy: 0.9260 - val_loss: 0.3157 - val_accuracy: 0.8961 - lr: 1.0000e-04
# Epoch 18/1000
# 25/25 [==============================] - 2s 72ms/step - loss: 0.2489 - accuracy: 0.9182 - val_loss: 0.4350 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 19/1000
# 25/25 [==============================] - 2s 70ms/step - loss: 0.2250 - accuracy: 0.9208 - val_loss: 0.2901 - val_accuracy: 0.8961 - lr: 1.0000e-04
# Epoch 20/1000
# 25/25 [==============================] - 2s 74ms/step - loss: 0.1809 - accuracy: 0.9403 - val_loss: 0.2653 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 21/1000
# 25/25 [==============================] - 2s 70ms/step - loss: 0.1821 - accuracy: 0.9403 - val_loss: 0.8156 - val_accuracy: 0.7727 - lr: 1.0000e-04
# Epoch 22/1000
# 25/25 [==============================] - 2s 72ms/step - loss: 0.3136 - accuracy: 0.8857 - val_loss: 0.2540 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 23/1000
# 25/25 [==============================] - 2s 65ms/step - loss: 0.1812 - accuracy: 0.9390 - val_loss: 0.1816 - val_accuracy: 0.9481 - lr: 1.0000e-04
# Epoch 24/1000
# 25/25 [==============================] - 2s 66ms/step - loss: 0.1242 - accuracy: 0.9649 - val_loss: 0.1884 - val_accuracy: 0.9481 - lr: 1.0000e-04
# Epoch 25/1000
# 25/25 [==============================] - 2s 73ms/step - loss: 0.1024 - accuracy: 0.9701 - val_loss: 0.1466 - val_accuracy: 0.9610 - lr: 1.0000e-04
# Epoch 26/1000
# 25/25 [==============================] - 2s 71ms/step - loss: 0.1717 - accuracy: 0.9286 - val_loss: 0.2761 - val_accuracy: 0.9221 - lr: 1.0000e-04
# Epoch 27/1000
# 25/25 [==============================] - 2s 69ms/step - loss: 0.3652 - accuracy: 0.8610 - val_loss: 0.2510 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 28/1000
# 25/25 [==============================] - 2s 74ms/step - loss: 0.1702 - accuracy: 0.9506 - val_loss: 0.2080 - val_accuracy: 0.9416 - lr: 1.0000e-04
# Epoch 29/1000
# 25/25 [==============================] - 2s 71ms/step - loss: 0.1379 - accuracy: 0.9571 - val_loss: 0.1455 - val_accuracy: 0.9610 - lr: 1.0000e-04
# Epoch 30/1000
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0921 - accuracy: 0.9766 - val_loss: 0.1930 - val_accuracy: 0.9416 - lr: 1.0000e-04
# Epoch 31/1000
# 25/25 [==============================] - 2s 63ms/step - loss: 0.0995 - accuracy: 0.9701 - val_loss: 0.1762 - val_accuracy: 0.9416 - lr: 1.0000e-04
# Epoch 32/1000
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0893 - accuracy: 0.9714 - val_loss: 0.3016 - val_accuracy: 0.9091 - lr: 1.0000e-04
# Epoch 33/1000
# 25/25 [==============================] - 2s 64ms/step - loss: 0.1267 - accuracy: 0.9610 - val_loss: 0.2295 - val_accuracy: 0.9156 - lr: 1.0000e-04
# Epoch 34/1000
# 25/25 [==============================] - 2s 69ms/step - loss: 0.1187 - accuracy: 0.9623 - val_loss: 0.1919 - val_accuracy: 0.9351 - lr: 1.0000e-04
# Epoch 35/1000
# 25/25 [==============================] - 2s 75ms/step - loss: 0.0900 - accuracy: 0.9714 - val_loss: 0.2247 - val_accuracy: 0.9416 - lr: 1.0000e-04
# Epoch 36/1000
# 25/25 [==============================] - 2s 67ms/step - loss: 0.1154 - accuracy: 0.9623 - val_loss: 0.2849 - val_accuracy: 0.9156 - lr: 1.0000e-04
# Epoch 37/1000
# 25/25 [==============================] - 2s 76ms/step - loss: 0.1876 - accuracy: 0.9299 - val_loss: 0.2058 - val_accuracy: 0.9351 - lr: 1.0000e-04
# Epoch 38/1000
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0873 - accuracy: 0.9740 - val_loss: 0.1463 - val_accuracy: 0.9481 - lr: 1.0000e-04
# Epoch 39/1000
# 25/25 [==============================] - 2s 77ms/step - loss: 0.0898 - accuracy: 0.9740 - val_loss: 0.1413 - val_accuracy: 0.9675 - lr: 1.0000e-04
# Epoch 40/1000
# 25/25 [==============================] - 2s 67ms/step - loss: 0.0685 - accuracy: 0.9792 - val_loss: 0.1419 - val_accuracy: 0.9610 - lr: 1.0000e-04
# Epoch 41/1000
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0698 - accuracy: 0.9740 - val_loss: 0.1309 - val_accuracy: 0.9675 - lr: 1.0000e-04
# Epoch 42/1000
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0452 - accuracy: 0.9844 - val_loss: 0.1148 - val_accuracy: 0.9675 - lr: 1.0000e-04
# Epoch 43/1000
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0484 - accuracy: 0.9818 - val_loss: 0.2596 - val_accuracy: 0.9221 - lr: 1.0000e-04
# Epoch 44/1000
# 25/25 [==============================] - 2s 69ms/step - loss: 0.0748 - accuracy: 0.9740 - val_loss: 0.1185 - val_accuracy: 0.9675 - lr: 1.0000e-04
# Epoch 45/1000
# 25/25 [==============================] - 2s 77ms/step - loss: 0.0313 - accuracy: 0.9922 - val_loss: 0.1035 - val_accuracy: 0.9740 - lr: 1.0000e-04
# Epoch 46/1000
# 25/25 [==============================] - 2s 76ms/step - loss: 0.0484 - accuracy: 0.9805 - val_loss: 0.2030 - val_accuracy: 0.9545 - lr: 1.0000e-04
# Epoch 47/1000
# 25/25 [==============================] - 2s 67ms/step - loss: 0.2112 - accuracy: 0.9299 - val_loss: 0.1859 - val_accuracy: 0.9416 - lr: 1.0000e-04
# Epoch 48/1000
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0669 - accuracy: 0.9831 - val_loss: 0.1953 - val_accuracy: 0.9286 - lr: 1.0000e-04
# Epoch 49/1000
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0694 - accuracy: 0.9766 - val_loss: 0.2272 - val_accuracy: 0.9221 - lr: 1.0000e-04
# Epoch 50/1000
# 25/25 [==============================] - 2s 87ms/step - loss: 0.0575 - accuracy: 0.9779 - val_loss: 0.1583 - val_accuracy: 0.9481 - lr: 1.0000e-04
# Epoch 51/1000
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0680 - accuracy: 0.9714 - val_loss: 0.1850 - val_accuracy: 0.9286 - lr: 1.0000e-04
# Epoch 52/1000
# 25/25 [==============================] - 2s 69ms/step - loss: 0.1388 - accuracy: 0.9519 - val_loss: 0.1187 - val_accuracy: 0.9740 - lr: 1.0000e-04
# Epoch 53/1000
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0668 - accuracy: 0.9766 - val_loss: 0.0959 - val_accuracy: 0.9675 - lr: 1.0000e-04
# Epoch 54/1000
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0448 - accuracy: 0.9896 - val_loss: 0.1389 - val_accuracy: 0.9675 - lr: 1.0000e-04
# Epoch 55/1000
# 25/25 [==============================] - 2s 67ms/step - loss: 0.0350 - accuracy: 0.9922 - val_loss: 0.0756 - val_accuracy: 0.9870 - lr: 1.0000e-04
# Epoch 56/1000
# 25/25 [==============================] - 2s 62ms/step - loss: 0.0540 - accuracy: 0.9831 - val_loss: 0.1541 - val_accuracy: 0.9545 - lr: 1.0000e-04
# Epoch 57/1000
# 25/25 [==============================] - 2s 68ms/step - loss: 0.0590 - accuracy: 0.9753 - val_loss: 0.1484 - val_accuracy: 0.9545 - lr: 1.0000e-04
# Epoch 58/1000
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0538 - accuracy: 0.9844 - val_loss: 0.1237 - val_accuracy: 0.9740 - lr: 1.0000e-04
# Epoch 59/1000
# 25/25 [==============================] - 2s 67ms/step - loss: 0.0303 - accuracy: 0.9922 - val_loss: 0.0881 - val_accuracy: 0.9805 - lr: 1.0000e-04
# Epoch 60/1000
# 25/25 [==============================] - 2s 65ms/step - loss: 0.0135 - accuracy: 0.9974 - val_loss: 0.0763 - val_accuracy: 0.9805 - lr: 1.0000e-04
# Epoch 61/1000
# 25/25 [==============================] - 2s 76ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9740 - lr: 1.0000e-04
# Epoch 62/1000
# 25/25 [==============================] - 2s 76ms/step - loss: 0.0065 - accuracy: 0.9987 - val_loss: 0.0732 - val_accuracy: 0.9805 - lr: 1.0000e-04
# Epoch 63/1000
# 25/25 [==============================] - 2s 67ms/step - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.0699 - val_accuracy: 0.9870 - lr: 1.0000e-04
# Epoch 64/1000
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0790 - val_accuracy: 0.9870 - lr: 1.0000e-04
# Epoch 65/1000
# 25/25 [==============================] - 2s 74ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9805 - lr: 1.0000e-04
# Epoch 66/1000
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 0.9805 - lr: 1.0000e-04
# Epoch 67/1000
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 0.9805 - lr: 1.0000e-04
# Epoch 68/1000
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9870 - lr: 1.0000e-04
# Epoch 69/1000
# 25/25 [==============================] - 2s 68ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9870 - lr: 1.0000e-04
# Epoch 70/1000
# 25/25 [==============================] - 2s 61ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 0.9870 - lr: 1.0000e-04
# Epoch 71/1000
# 25/25 [==============================] - 2s 69ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9870 - lr: 1.0000e-04
# Epoch 72/1000
# 25/25 [==============================] - 2s 67ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9870 - lr: 1.0000e-04
# Epoch 73/1000
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9870 - lr: 1.0000e-04
# Epoch 74/1000
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9870 - lr: 8.0000e-05
# Epoch 75/1000
# 25/25 [==============================] - 2s 63ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9870 - lr: 8.0000e-05
# Epoch 76/1000
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9805 - lr: 8.0000e-05
# Epoch 77/1000
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1022 - val_accuracy: 0.9805 - lr: 8.0000e-05
# Epoch 78/1000
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0985 - val_accuracy: 0.9805 - lr: 8.0000e-05
# Epoch 79/1000
# 25/25 [==============================] - 2s 78ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 0.9870 - lr: 8.0000e-05
# Epoch 80/1000
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 0.9870 - lr: 8.0000e-05
# Epoch 81/1000
# 25/25 [==============================] - 2s 74ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9870 - lr: 8.0000e-05
# Epoch 82/1000
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9870 - lr: 8.0000e-05
# Epoch 83/1000
# 25/25 [==============================] - 2s 70ms/step - loss: 9.2071e-04 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9870 - lr: 8.0000e-05

# %%
model.evaluate(X_test, y_test, return_dict=True)
# Out:
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0234 - accuracy: 0.9943
# {'loss': 0.023448677733540535, 'accuracy': 0.9943181872367859}

# %%
def plot_history(history, imagename=False):
    """
    Plotting training and validation learning curves.
    
    Args:
        history: model history with all the metric measures
    """
    fig, (ax1, ax2) = plt.subplots(2)
    
    fig.set_size_inches(18.5, 10.5)
    
    # Plot loss
    ax1.set_title('Loss')
    ax1.plot(history.history['loss'], label = 'train')
    ax1.plot(history.history['val_loss'], label = 'test')
    ax1.set_ylabel('Loss')
    
    # Determine upper bound of y-axis
    max_loss = max(history.history['loss'] + history.history['val_loss'])
    
    ax1.set_ylim([0, np.ceil(max_loss)])
    ax1.set_xlabel('Epoch')
    ax1.legend(['Train', 'Validation']) 
    
    # Plot accuracy
    ax2.set_title('Accuracy')
    ax2.plot(history.history['accuracy'],  label = 'train')
    ax2.plot(history.history['val_accuracy'], label = 'test')
    ax2.set_ylabel('Accuracy')
    ax2.set_ylim([0, 1])
    ax2.set_xlabel('Epoch')
    ax2.legend(['Train', 'Validation'])
    plt.tight_layout()
    if imagename:
        plt.savefig(imagename)
    plt.show()

plot_history(history)

# %%
model.save(r"C:\Users\wegar\CNN-LSTM Deadlift Classification\Saved Models\LSTM KPS\CNN-LSTM base.keras")

# %%
import pickle
with open(r"C:\Users\wegar\CNN-LSTM Deadlift Classification\Saved Models\LSTM KPS\CNN-LSTM base history.pkl", "wb") as f:
    pickle.dump(history.history, f)
