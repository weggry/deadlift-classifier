# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import pathlib

# Random seed for reproducability
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

from keras.models import Sequential
from keras.layers import LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

import json
# Loading dataset splits from JSON into correct paths for the model
with open(r"C:\Users\wegar\Deadlift Classification v2\splits\v2 split.json", "r") as f:
    splits = json.load(f) # Loads the dictionary of train, test, val clip distribution (only names, not paths)

video_folder = pathlib.Path(r"C:\Users\wegar\Deadlift Classification v2\KPS arrays")

# Filter only S_ occurrences into subsets
subset_paths = {
    split: [video_folder / f"{fname}.npy" for fname in splits[split] if fname.startswith("S_")]
    for split in ["train", "val", "test"]
}

# %%
print(f"Train set files: {len(subset_paths['train'])}")
print(f"Val set files: {len(subset_paths['val'])}")
print(f"Test set files: {len(subset_paths['test'])}")
# Out:
# Train set files: 280
# Val set files: 56
# Test set files: 64

# %%
frame_lengths = [np.load(array).shape[0] for array in subset_paths["train"]]

print("Min frames:", min(frame_lengths))
print("Max frames:", max(frame_lengths))
print("Mean frames:", np.mean(frame_lengths))
print("Median frames:", np.median(frame_lengths))
# Out:
# Min frames: 138
# Max frames: 301
# Mean frames: 190.59285714285716
# Median frames: 187.5

# %%
def interpolate_kps(kps, target_frames=200):
    frames, features = kps.shape  # features = 51

    interpolated = np.zeros((target_frames, features), dtype=np.float32)
    for i in range(features):
        interpolated[:, i] = np.interp(
            np.linspace(0, frames - 1, target_frames),
            np.arange(frames),
            kps[:, i]
        )
    return interpolated


unique_labels = set(fname.split("_")[1] for split in splits for fname in splits[split] if fname.startswith("S_"))


label_dict = {label: idx for idx, label in enumerate(sorted(unique_labels))}

def load_data(split):
    X = []
    y = []
    for array in subset_paths[split]:
        kps = np.load(array).reshape(-1, 51)
        kps_interp = interpolate_kps(kps, target_frames=200)
        X.append(kps_interp)

        fname = array.stem  
        label = fname.split("_")[1]
        y.append(label_dict[label])

    y = to_categorical(y, num_classes=len(label_dict)) # One-hot encoding
    return np.array(X), np.array(y)

X_train, y_train = load_data('train')
X_val, y_val = load_data('val')
X_test, y_test = load_data('test')

# %%
idx_to_label = {v: k for k, v in label_dict.items()}
print(idx_to_label)
# Out:
# {0: 'corr', 1: 'ehe', 2: 'oe', 3: 'rb'}

# %%
from sklearn.utils import shuffle

X_train, y_train = shuffle(X_train, y_train, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, ReLU, Dropout, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau


reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.8, patience=10, min_lr=5e-6
)

optimizer = Adam(learning_rate=1e-4)
verbose, epochs, batch_size = 1, 1000, 32
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train.shape[1]

model = Sequential([
    LSTM(256, return_sequences=True, input_shape=(n_timesteps, n_features)),
    LSTM(128),
    Dropout(0.5),
    Dense(128, activation="relu"),
    Dense(n_outputs, activation='softmax')
])

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=80,
    restore_best_weights=True
)

history = model.fit(X_train, y_train, 
                    epochs=epochs, 
                    validation_data = (X_val, y_val),
                    batch_size=batch_size, 
                    callbacks=[early_stop, reduce_lr],
                    verbose=verbose)
# Out:
# Epoch 1/1000
# 9/9 [==============================] - 4s 166ms/step - loss: 1.4083 - accuracy: 0.2071 - val_loss: 1.3848 - val_accuracy: 0.2500 - lr: 1.0000e-04
# Epoch 2/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 1.3971 - accuracy: 0.2464 - val_loss: 1.3816 - val_accuracy: 0.2500 - lr: 1.0000e-04
# Epoch 3/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.3864 - accuracy: 0.2250 - val_loss: 1.3777 - val_accuracy: 0.3750 - lr: 1.0000e-04
# Epoch 4/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 1.3836 - accuracy: 0.2393 - val_loss: 1.3752 - val_accuracy: 0.4107 - lr: 1.0000e-04
# Epoch 5/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 1.3828 - accuracy: 0.2607 - val_loss: 1.3716 - val_accuracy: 0.2500 - lr: 1.0000e-04
# Epoch 6/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 1.3947 - accuracy: 0.2143 - val_loss: 1.3656 - val_accuracy: 0.2857 - lr: 1.0000e-04
# Epoch 7/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 1.3769 - accuracy: 0.2929 - val_loss: 1.3584 - val_accuracy: 0.4643 - lr: 1.0000e-04
# Epoch 8/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 1.3613 - accuracy: 0.3214 - val_loss: 1.3503 - val_accuracy: 0.4464 - lr: 1.0000e-04
# Epoch 9/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.3689 - accuracy: 0.2786 - val_loss: 1.3346 - val_accuracy: 0.4286 - lr: 1.0000e-04
# Epoch 10/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3476 - accuracy: 0.3464 - val_loss: 1.3150 - val_accuracy: 0.4464 - lr: 1.0000e-04
# Epoch 11/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 1.3365 - accuracy: 0.3750 - val_loss: 1.2833 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 12/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 1.3039 - accuracy: 0.3571 - val_loss: 1.2192 - val_accuracy: 0.4643 - lr: 1.0000e-04
# Epoch 13/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2778 - accuracy: 0.3679 - val_loss: 1.2523 - val_accuracy: 0.3750 - lr: 1.0000e-04
# Epoch 14/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 1.2718 - accuracy: 0.3929 - val_loss: 1.1661 - val_accuracy: 0.4464 - lr: 1.0000e-04
# Epoch 15/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 1.2644 - accuracy: 0.3750 - val_loss: 1.1676 - val_accuracy: 0.4286 - lr: 1.0000e-04
# Epoch 16/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 1.2263 - accuracy: 0.4536 - val_loss: 1.1341 - val_accuracy: 0.4286 - lr: 1.0000e-04
# Epoch 17/1000
# 9/9 [==============================] - 1s 67ms/step - loss: 1.1335 - accuracy: 0.4929 - val_loss: 1.0871 - val_accuracy: 0.4821 - lr: 1.0000e-04
# Epoch 18/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 1.2250 - accuracy: 0.4214 - val_loss: 1.2348 - val_accuracy: 0.4643 - lr: 1.0000e-04
# Epoch 19/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4545 - accuracy: 0.3607 - val_loss: 1.5288 - val_accuracy: 0.2500 - lr: 1.0000e-04
# Epoch 20/1000
# 9/9 [==============================] - 1s 66ms/step - loss: 1.4754 - accuracy: 0.2821 - val_loss: 1.3432 - val_accuracy: 0.3036 - lr: 1.0000e-04
# Epoch 21/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3522 - accuracy: 0.3000 - val_loss: 1.3258 - val_accuracy: 0.3929 - lr: 1.0000e-04
# Epoch 22/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 1.3511 - accuracy: 0.3036 - val_loss: 1.3129 - val_accuracy: 0.4464 - lr: 1.0000e-04
# Epoch 23/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.3239 - accuracy: 0.3464 - val_loss: 1.2892 - val_accuracy: 0.4464 - lr: 1.0000e-04
# Epoch 24/1000
# 9/9 [==============================] - 1s 80ms/step - loss: 1.2991 - accuracy: 0.4714 - val_loss: 1.2641 - val_accuracy: 0.4464 - lr: 1.0000e-04
# Epoch 25/1000
# 9/9 [==============================] - 1s 82ms/step - loss: 1.2732 - accuracy: 0.4464 - val_loss: 1.2254 - val_accuracy: 0.4643 - lr: 1.0000e-04
# Epoch 26/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 1.2610 - accuracy: 0.3964 - val_loss: 1.2042 - val_accuracy: 0.4107 - lr: 1.0000e-04
# Epoch 27/1000
# 9/9 [==============================] - 1s 80ms/step - loss: 1.2186 - accuracy: 0.4500 - val_loss: 1.1715 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 28/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2105 - accuracy: 0.4357 - val_loss: 1.1706 - val_accuracy: 0.4107 - lr: 8.0000e-05
# Epoch 29/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 1.1787 - accuracy: 0.4500 - val_loss: 1.1467 - val_accuracy: 0.4821 - lr: 8.0000e-05
# Epoch 30/1000
# 9/9 [==============================] - 1s 69ms/step - loss: 1.1656 - accuracy: 0.4821 - val_loss: 1.1481 - val_accuracy: 0.4464 - lr: 8.0000e-05
# Epoch 31/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 1.1502 - accuracy: 0.4679 - val_loss: 1.1531 - val_accuracy: 0.4107 - lr: 8.0000e-05
# Epoch 32/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 1.1553 - accuracy: 0.4929 - val_loss: 1.1304 - val_accuracy: 0.4643 - lr: 8.0000e-05
# Epoch 33/1000
# 9/9 [==============================] - 1s 82ms/step - loss: 1.1424 - accuracy: 0.4857 - val_loss: 1.1164 - val_accuracy: 0.5000 - lr: 8.0000e-05
# Epoch 34/1000
# 9/9 [==============================] - 1s 79ms/step - loss: 1.1644 - accuracy: 0.4786 - val_loss: 1.1732 - val_accuracy: 0.4286 - lr: 8.0000e-05
# Epoch 35/1000
# 9/9 [==============================] - 1s 89ms/step - loss: 1.1733 - accuracy: 0.4429 - val_loss: 1.1140 - val_accuracy: 0.4464 - lr: 8.0000e-05
# Epoch 36/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 1.0978 - accuracy: 0.4893 - val_loss: 1.0824 - val_accuracy: 0.4643 - lr: 8.0000e-05
# Epoch 37/1000
# 9/9 [==============================] - 1s 82ms/step - loss: 1.1052 - accuracy: 0.4893 - val_loss: 1.0776 - val_accuracy: 0.5000 - lr: 8.0000e-05
# Epoch 38/1000
# 9/9 [==============================] - 1s 85ms/step - loss: 1.0798 - accuracy: 0.5036 - val_loss: 1.0609 - val_accuracy: 0.5000 - lr: 8.0000e-05
# Epoch 39/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 1.0803 - accuracy: 0.5000 - val_loss: 1.0372 - val_accuracy: 0.5000 - lr: 8.0000e-05
# Epoch 40/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 1.0735 - accuracy: 0.4821 - val_loss: 1.0652 - val_accuracy: 0.4821 - lr: 8.0000e-05
# Epoch 41/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 1.0882 - accuracy: 0.4679 - val_loss: 1.0486 - val_accuracy: 0.4821 - lr: 8.0000e-05
# Epoch 42/1000
# 9/9 [==============================] - 1s 80ms/step - loss: 1.0423 - accuracy: 0.5429 - val_loss: 0.9594 - val_accuracy: 0.5179 - lr: 8.0000e-05
# Epoch 43/1000
# 9/9 [==============================] - 1s 68ms/step - loss: 1.0366 - accuracy: 0.5143 - val_loss: 0.9922 - val_accuracy: 0.4821 - lr: 8.0000e-05
# Epoch 44/1000
# 9/9 [==============================] - 1s 69ms/step - loss: 0.9944 - accuracy: 0.5250 - val_loss: 0.9303 - val_accuracy: 0.5714 - lr: 8.0000e-05
# Epoch 45/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 1.0363 - accuracy: 0.5036 - val_loss: 0.9163 - val_accuracy: 0.5714 - lr: 8.0000e-05
# Epoch 46/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 0.9727 - accuracy: 0.5679 - val_loss: 0.8879 - val_accuracy: 0.6071 - lr: 8.0000e-05
# Epoch 47/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 0.9254 - accuracy: 0.5536 - val_loss: 0.8700 - val_accuracy: 0.5893 - lr: 8.0000e-05
# Epoch 48/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.9012 - accuracy: 0.5750 - val_loss: 0.8458 - val_accuracy: 0.5893 - lr: 8.0000e-05
# Epoch 49/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.9332 - accuracy: 0.5786 - val_loss: 0.8739 - val_accuracy: 0.5357 - lr: 8.0000e-05
# Epoch 50/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.8690 - accuracy: 0.5821 - val_loss: 0.7985 - val_accuracy: 0.6250 - lr: 8.0000e-05
# Epoch 51/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.8330 - accuracy: 0.6286 - val_loss: 0.8679 - val_accuracy: 0.5357 - lr: 8.0000e-05
# Epoch 52/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.8613 - accuracy: 0.5964 - val_loss: 0.8712 - val_accuracy: 0.6250 - lr: 8.0000e-05
# Epoch 53/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.8744 - accuracy: 0.5679 - val_loss: 0.7994 - val_accuracy: 0.6250 - lr: 8.0000e-05
# Epoch 54/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.8818 - accuracy: 0.5821 - val_loss: 0.7891 - val_accuracy: 0.6250 - lr: 8.0000e-05
# Epoch 55/1000
# 9/9 [==============================] - 1s 69ms/step - loss: 0.8879 - accuracy: 0.5893 - val_loss: 0.7343 - val_accuracy: 0.6071 - lr: 8.0000e-05
# Epoch 56/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.9516 - accuracy: 0.5714 - val_loss: 0.7947 - val_accuracy: 0.6071 - lr: 8.0000e-05
# Epoch 57/1000
# 9/9 [==============================] - 1s 88ms/step - loss: 0.9301 - accuracy: 0.5821 - val_loss: 0.7964 - val_accuracy: 0.6071 - lr: 8.0000e-05
# Epoch 58/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 0.8755 - accuracy: 0.5857 - val_loss: 0.8699 - val_accuracy: 0.6250 - lr: 8.0000e-05
# Epoch 59/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.8623 - accuracy: 0.5929 - val_loss: 0.7150 - val_accuracy: 0.6786 - lr: 8.0000e-05
# Epoch 60/1000
# 9/9 [==============================] - 1s 69ms/step - loss: 0.7759 - accuracy: 0.6393 - val_loss: 0.7253 - val_accuracy: 0.6607 - lr: 8.0000e-05
# Epoch 61/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.7613 - accuracy: 0.6464 - val_loss: 0.7450 - val_accuracy: 0.6964 - lr: 8.0000e-05
# Epoch 62/1000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.8552 - accuracy: 0.6286 - val_loss: 0.6882 - val_accuracy: 0.6964 - lr: 8.0000e-05
# Epoch 63/1000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.7537 - accuracy: 0.6571 - val_loss: 0.6365 - val_accuracy: 0.7679 - lr: 8.0000e-05
# Epoch 64/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.7119 - accuracy: 0.6929 - val_loss: 0.6454 - val_accuracy: 0.7500 - lr: 8.0000e-05
# Epoch 65/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.6980 - accuracy: 0.6607 - val_loss: 0.6787 - val_accuracy: 0.7143 - lr: 8.0000e-05
# Epoch 66/1000
# 9/9 [==============================] - 1s 68ms/step - loss: 0.7362 - accuracy: 0.6179 - val_loss: 0.7568 - val_accuracy: 0.7321 - lr: 8.0000e-05
# Epoch 67/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.7334 - accuracy: 0.6786 - val_loss: 0.6675 - val_accuracy: 0.7857 - lr: 8.0000e-05
# Epoch 68/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.7722 - accuracy: 0.6464 - val_loss: 0.6831 - val_accuracy: 0.6607 - lr: 8.0000e-05
# Epoch 69/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.7526 - accuracy: 0.6536 - val_loss: 0.6895 - val_accuracy: 0.7143 - lr: 8.0000e-05
# Epoch 70/1000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.7222 - accuracy: 0.7000 - val_loss: 0.7653 - val_accuracy: 0.6964 - lr: 8.0000e-05
# Epoch 71/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.8363 - accuracy: 0.6179 - val_loss: 0.8710 - val_accuracy: 0.6429 - lr: 8.0000e-05
# Epoch 72/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.7893 - accuracy: 0.6357 - val_loss: 0.6507 - val_accuracy: 0.7321 - lr: 8.0000e-05
# Epoch 73/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.7432 - accuracy: 0.6929 - val_loss: 0.6054 - val_accuracy: 0.7321 - lr: 8.0000e-05
# Epoch 74/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6854 - accuracy: 0.7071 - val_loss: 0.6373 - val_accuracy: 0.7143 - lr: 8.0000e-05
# Epoch 75/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6949 - accuracy: 0.6786 - val_loss: 0.7431 - val_accuracy: 0.6429 - lr: 8.0000e-05
# Epoch 76/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.8174 - accuracy: 0.6143 - val_loss: 0.8607 - val_accuracy: 0.6429 - lr: 8.0000e-05
# Epoch 77/1000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.8141 - accuracy: 0.6643 - val_loss: 0.5690 - val_accuracy: 0.8214 - lr: 8.0000e-05
# Epoch 78/1000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.6829 - accuracy: 0.7393 - val_loss: 0.6122 - val_accuracy: 0.7500 - lr: 8.0000e-05
# Epoch 79/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6493 - accuracy: 0.7214 - val_loss: 0.5525 - val_accuracy: 0.8036 - lr: 8.0000e-05
# Epoch 80/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.6085 - accuracy: 0.7536 - val_loss: 0.5470 - val_accuracy: 0.7857 - lr: 8.0000e-05
# Epoch 81/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6440 - accuracy: 0.7214 - val_loss: 0.7240 - val_accuracy: 0.6250 - lr: 8.0000e-05
# Epoch 82/1000
# 9/9 [==============================] - 1s 80ms/step - loss: 0.6581 - accuracy: 0.7000 - val_loss: 0.5494 - val_accuracy: 0.8036 - lr: 8.0000e-05
# Epoch 83/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6779 - accuracy: 0.6964 - val_loss: 0.5742 - val_accuracy: 0.7143 - lr: 8.0000e-05
# Epoch 84/1000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.6931 - accuracy: 0.6821 - val_loss: 0.7054 - val_accuracy: 0.6964 - lr: 8.0000e-05
# Epoch 85/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.5977 - accuracy: 0.6964 - val_loss: 0.5799 - val_accuracy: 0.7857 - lr: 8.0000e-05
# Epoch 86/1000
# 9/9 [==============================] - 1s 67ms/step - loss: 0.5533 - accuracy: 0.7679 - val_loss: 0.5781 - val_accuracy: 0.8036 - lr: 8.0000e-05
# Epoch 87/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.5912 - accuracy: 0.7179 - val_loss: 0.7448 - val_accuracy: 0.6607 - lr: 8.0000e-05
# Epoch 88/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6101 - accuracy: 0.7321 - val_loss: 0.5613 - val_accuracy: 0.7679 - lr: 8.0000e-05
# Epoch 89/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.6145 - accuracy: 0.7357 - val_loss: 0.5476 - val_accuracy: 0.8214 - lr: 8.0000e-05
# Epoch 90/1000
# 9/9 [==============================] - 1s 65ms/step - loss: 0.5318 - accuracy: 0.7786 - val_loss: 0.4961 - val_accuracy: 0.8393 - lr: 8.0000e-05
# Epoch 91/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.5333 - accuracy: 0.7714 - val_loss: 0.4519 - val_accuracy: 0.8393 - lr: 8.0000e-05
# Epoch 92/1000
# 9/9 [==============================] - 1s 79ms/step - loss: 0.5126 - accuracy: 0.7714 - val_loss: 0.4502 - val_accuracy: 0.8036 - lr: 8.0000e-05
# Epoch 93/1000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.4974 - accuracy: 0.8000 - val_loss: 0.4641 - val_accuracy: 0.8214 - lr: 8.0000e-05
# Epoch 94/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.5041 - accuracy: 0.7786 - val_loss: 0.4358 - val_accuracy: 0.8393 - lr: 8.0000e-05
# Epoch 95/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.5008 - accuracy: 0.7964 - val_loss: 0.4264 - val_accuracy: 0.8571 - lr: 8.0000e-05
# Epoch 96/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.4671 - accuracy: 0.8250 - val_loss: 0.4973 - val_accuracy: 0.7857 - lr: 8.0000e-05
# Epoch 97/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 0.4549 - accuracy: 0.8321 - val_loss: 0.4166 - val_accuracy: 0.8571 - lr: 8.0000e-05
# Epoch 98/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.4509 - accuracy: 0.8071 - val_loss: 0.5474 - val_accuracy: 0.7857 - lr: 8.0000e-05
# Epoch 99/1000
# 9/9 [==============================] - 1s 79ms/step - loss: 0.6755 - accuracy: 0.7286 - val_loss: 0.5106 - val_accuracy: 0.7857 - lr: 8.0000e-05
# Epoch 100/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.4650 - accuracy: 0.8143 - val_loss: 0.4511 - val_accuracy: 0.8036 - lr: 8.0000e-05
# Epoch 101/1000
# 9/9 [==============================] - 1s 67ms/step - loss: 0.4549 - accuracy: 0.8107 - val_loss: 0.4869 - val_accuracy: 0.7857 - lr: 8.0000e-05
# Epoch 102/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.4189 - accuracy: 0.8321 - val_loss: 0.4308 - val_accuracy: 0.8393 - lr: 8.0000e-05
# Epoch 103/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.4088 - accuracy: 0.8393 - val_loss: 0.4669 - val_accuracy: 0.8036 - lr: 8.0000e-05
# Epoch 104/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.3603 - accuracy: 0.8964 - val_loss: 0.4517 - val_accuracy: 0.8393 - lr: 8.0000e-05
# Epoch 105/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.3635 - accuracy: 0.8643 - val_loss: 0.5260 - val_accuracy: 0.8393 - lr: 8.0000e-05
# Epoch 106/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.5489 - accuracy: 0.7857 - val_loss: 0.5240 - val_accuracy: 0.8036 - lr: 8.0000e-05
# Epoch 107/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.4596 - accuracy: 0.8286 - val_loss: 0.5208 - val_accuracy: 0.8393 - lr: 8.0000e-05
# Epoch 108/1000
# 9/9 [==============================] - 1s 79ms/step - loss: 0.4309 - accuracy: 0.8357 - val_loss: 0.4503 - val_accuracy: 0.8214 - lr: 6.4000e-05
# Epoch 109/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.3621 - accuracy: 0.8536 - val_loss: 0.5150 - val_accuracy: 0.8214 - lr: 6.4000e-05
# Epoch 110/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2948 - accuracy: 0.8964 - val_loss: 0.4632 - val_accuracy: 0.8571 - lr: 6.4000e-05
# Epoch 111/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.3152 - accuracy: 0.9000 - val_loss: 0.4598 - val_accuracy: 0.8571 - lr: 6.4000e-05
# Epoch 112/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 0.2869 - accuracy: 0.9036 - val_loss: 0.4655 - val_accuracy: 0.8393 - lr: 6.4000e-05
# Epoch 113/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2780 - accuracy: 0.9107 - val_loss: 0.4851 - val_accuracy: 0.8393 - lr: 6.4000e-05
# Epoch 114/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.2621 - accuracy: 0.9214 - val_loss: 0.5362 - val_accuracy: 0.8036 - lr: 6.4000e-05
# Epoch 115/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2677 - accuracy: 0.9143 - val_loss: 0.7003 - val_accuracy: 0.7679 - lr: 6.4000e-05
# Epoch 116/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.2843 - accuracy: 0.9071 - val_loss: 0.4644 - val_accuracy: 0.8393 - lr: 6.4000e-05
# Epoch 117/1000
# 9/9 [==============================] - 1s 68ms/step - loss: 0.3482 - accuracy: 0.8786 - val_loss: 0.5489 - val_accuracy: 0.8214 - lr: 6.4000e-05
# Epoch 118/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2802 - accuracy: 0.9000 - val_loss: 0.6249 - val_accuracy: 0.7321 - lr: 5.1200e-05
# Epoch 119/1000
# 9/9 [==============================] - 1s 62ms/step - loss: 0.2469 - accuracy: 0.9036 - val_loss: 0.4023 - val_accuracy: 0.8750 - lr: 5.1200e-05
# Epoch 120/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.2500 - accuracy: 0.9143 - val_loss: 0.6181 - val_accuracy: 0.8036 - lr: 5.1200e-05
# Epoch 121/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2531 - accuracy: 0.9071 - val_loss: 0.6634 - val_accuracy: 0.7321 - lr: 5.1200e-05
# Epoch 122/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.3206 - accuracy: 0.8821 - val_loss: 0.8456 - val_accuracy: 0.6964 - lr: 5.1200e-05
# Epoch 123/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.3538 - accuracy: 0.8607 - val_loss: 0.5763 - val_accuracy: 0.8036 - lr: 5.1200e-05
# Epoch 124/1000
# 9/9 [==============================] - 1s 69ms/step - loss: 0.3127 - accuracy: 0.8893 - val_loss: 0.4728 - val_accuracy: 0.8214 - lr: 5.1200e-05
# Epoch 125/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.3168 - accuracy: 0.8750 - val_loss: 0.5418 - val_accuracy: 0.8036 - lr: 5.1200e-05
# Epoch 126/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2707 - accuracy: 0.8893 - val_loss: 0.5717 - val_accuracy: 0.7857 - lr: 5.1200e-05
# Epoch 127/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.2225 - accuracy: 0.9321 - val_loss: 0.5923 - val_accuracy: 0.7857 - lr: 5.1200e-05
# Epoch 128/1000
# 9/9 [==============================] - 1s 67ms/step - loss: 0.2131 - accuracy: 0.9250 - val_loss: 0.4599 - val_accuracy: 0.8393 - lr: 5.1200e-05
# Epoch 129/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2070 - accuracy: 0.9321 - val_loss: 0.5377 - val_accuracy: 0.8214 - lr: 5.1200e-05
# Epoch 130/1000
# 9/9 [==============================] - 1s 67ms/step - loss: 0.1731 - accuracy: 0.9607 - val_loss: 0.4228 - val_accuracy: 0.8750 - lr: 4.0960e-05
# Epoch 131/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.2042 - accuracy: 0.9393 - val_loss: 0.5085 - val_accuracy: 0.8393 - lr: 4.0960e-05
# Epoch 132/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.1509 - accuracy: 0.9679 - val_loss: 0.5272 - val_accuracy: 0.8393 - lr: 4.0960e-05
# Epoch 133/1000
# 9/9 [==============================] - 1s 66ms/step - loss: 0.1693 - accuracy: 0.9607 - val_loss: 0.5464 - val_accuracy: 0.7857 - lr: 4.0960e-05
# Epoch 134/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.1200 - accuracy: 0.9750 - val_loss: 0.5196 - val_accuracy: 0.8036 - lr: 4.0960e-05
# Epoch 135/1000
# 9/9 [==============================] - 1s 67ms/step - loss: 0.1138 - accuracy: 0.9679 - val_loss: 0.5134 - val_accuracy: 0.8214 - lr: 4.0960e-05
# Epoch 136/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.1211 - accuracy: 0.9750 - val_loss: 0.4970 - val_accuracy: 0.8571 - lr: 4.0960e-05
# Epoch 137/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0926 - accuracy: 0.9821 - val_loss: 0.5380 - val_accuracy: 0.8036 - lr: 4.0960e-05
# Epoch 138/1000
# 9/9 [==============================] - 1s 68ms/step - loss: 0.1000 - accuracy: 0.9857 - val_loss: 0.5268 - val_accuracy: 0.8214 - lr: 4.0960e-05
# Epoch 139/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0905 - accuracy: 0.9857 - val_loss: 0.5514 - val_accuracy: 0.8393 - lr: 4.0960e-05
# Epoch 140/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.0927 - accuracy: 0.9821 - val_loss: 0.5096 - val_accuracy: 0.8393 - lr: 3.2768e-05
# Epoch 141/1000
# 9/9 [==============================] - 1s 80ms/step - loss: 0.1128 - accuracy: 0.9679 - val_loss: 0.5567 - val_accuracy: 0.8214 - lr: 3.2768e-05
# Epoch 142/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0917 - accuracy: 0.9750 - val_loss: 0.5566 - val_accuracy: 0.8214 - lr: 3.2768e-05
# Epoch 143/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.1062 - accuracy: 0.9750 - val_loss: 0.5963 - val_accuracy: 0.8036 - lr: 3.2768e-05
# Epoch 144/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.1078 - accuracy: 0.9750 - val_loss: 0.5394 - val_accuracy: 0.8214 - lr: 3.2768e-05
# Epoch 145/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.0856 - accuracy: 0.9857 - val_loss: 0.5325 - val_accuracy: 0.8393 - lr: 3.2768e-05
# Epoch 146/1000
# 9/9 [==============================] - 1s 66ms/step - loss: 0.0754 - accuracy: 0.9929 - val_loss: 0.5564 - val_accuracy: 0.8036 - lr: 3.2768e-05
# Epoch 147/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.0702 - accuracy: 0.9893 - val_loss: 0.6019 - val_accuracy: 0.8036 - lr: 3.2768e-05
# Epoch 148/1000
# 9/9 [==============================] - 1s 69ms/step - loss: 0.0820 - accuracy: 0.9857 - val_loss: 0.5560 - val_accuracy: 0.8214 - lr: 3.2768e-05
# Epoch 149/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.0775 - accuracy: 0.9893 - val_loss: 0.5928 - val_accuracy: 0.8214 - lr: 3.2768e-05
# Epoch 150/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0701 - accuracy: 0.9893 - val_loss: 0.5473 - val_accuracy: 0.8393 - lr: 2.6214e-05
# Epoch 151/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.0687 - accuracy: 0.9893 - val_loss: 0.5997 - val_accuracy: 0.8036 - lr: 2.6214e-05
# Epoch 152/1000
# 9/9 [==============================] - 1s 67ms/step - loss: 0.0678 - accuracy: 0.9857 - val_loss: 0.6035 - val_accuracy: 0.8214 - lr: 2.6214e-05
# Epoch 153/1000
# 9/9 [==============================] - 1s 62ms/step - loss: 0.0764 - accuracy: 0.9786 - val_loss: 0.6464 - val_accuracy: 0.8036 - lr: 2.6214e-05
# Epoch 154/1000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0634 - accuracy: 0.9893 - val_loss: 0.6465 - val_accuracy: 0.8036 - lr: 2.6214e-05
# Epoch 155/1000
# 9/9 [==============================] - 1s 68ms/step - loss: 0.0828 - accuracy: 0.9857 - val_loss: 0.5441 - val_accuracy: 0.8393 - lr: 2.6214e-05
# Epoch 156/1000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.0798 - accuracy: 0.9821 - val_loss: 0.4905 - val_accuracy: 0.8571 - lr: 2.6214e-05
# Epoch 157/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.1149 - accuracy: 0.9679 - val_loss: 0.6758 - val_accuracy: 0.7857 - lr: 2.6214e-05
# Epoch 158/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.1199 - accuracy: 0.9607 - val_loss: 0.5905 - val_accuracy: 0.8036 - lr: 2.6214e-05
# Epoch 159/1000
# 9/9 [==============================] - 1s 65ms/step - loss: 0.1923 - accuracy: 0.9357 - val_loss: 0.6030 - val_accuracy: 0.8393 - lr: 2.6214e-05
# Epoch 160/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0809 - accuracy: 0.9893 - val_loss: 0.6137 - val_accuracy: 0.8393 - lr: 2.0972e-05
# Epoch 161/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.0635 - accuracy: 0.9893 - val_loss: 0.6314 - val_accuracy: 0.7857 - lr: 2.0972e-05
# Epoch 162/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0882 - accuracy: 0.9786 - val_loss: 0.5324 - val_accuracy: 0.8393 - lr: 2.0972e-05
# Epoch 163/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.0640 - accuracy: 0.9857 - val_loss: 0.5896 - val_accuracy: 0.8393 - lr: 2.0972e-05
# Epoch 164/1000
# 9/9 [==============================] - 1s 69ms/step - loss: 0.0629 - accuracy: 0.9893 - val_loss: 0.5892 - val_accuracy: 0.8214 - lr: 2.0972e-05
# Epoch 165/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0656 - accuracy: 0.9857 - val_loss: 0.6022 - val_accuracy: 0.8214 - lr: 2.0972e-05
# Epoch 166/1000
# 9/9 [==============================] - 1s 67ms/step - loss: 0.0549 - accuracy: 0.9929 - val_loss: 0.6193 - val_accuracy: 0.8036 - lr: 2.0972e-05
# Epoch 167/1000
# 9/9 [==============================] - 1s 66ms/step - loss: 0.0534 - accuracy: 0.9929 - val_loss: 0.6030 - val_accuracy: 0.8214 - lr: 2.0972e-05
# Epoch 168/1000
# 9/9 [==============================] - 1s 65ms/step - loss: 0.0529 - accuracy: 0.9929 - val_loss: 0.6015 - val_accuracy: 0.8393 - lr: 2.0972e-05
# Epoch 169/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.0469 - accuracy: 0.9964 - val_loss: 0.6000 - val_accuracy: 0.8036 - lr: 2.0972e-05
# Epoch 170/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.0510 - accuracy: 0.9929 - val_loss: 0.6135 - val_accuracy: 0.8214 - lr: 1.6777e-05
# Epoch 171/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.0482 - accuracy: 0.9964 - val_loss: 0.5924 - val_accuracy: 0.8214 - lr: 1.6777e-05
# Epoch 172/1000
# 9/9 [==============================] - 1s 69ms/step - loss: 0.0547 - accuracy: 0.9929 - val_loss: 0.5900 - val_accuracy: 0.8036 - lr: 1.6777e-05
# Epoch 173/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0472 - accuracy: 0.9929 - val_loss: 0.5959 - val_accuracy: 0.8214 - lr: 1.6777e-05
# Epoch 174/1000
# 9/9 [==============================] - 1s 68ms/step - loss: 0.0502 - accuracy: 0.9893 - val_loss: 0.5795 - val_accuracy: 0.8393 - lr: 1.6777e-05
# Epoch 175/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0457 - accuracy: 0.9964 - val_loss: 0.5831 - val_accuracy: 0.8571 - lr: 1.6777e-05
# Epoch 176/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.0427 - accuracy: 0.9929 - val_loss: 0.5943 - val_accuracy: 0.8036 - lr: 1.6777e-05
# Epoch 177/1000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.0529 - accuracy: 0.9929 - val_loss: 0.5904 - val_accuracy: 0.8393 - lr: 1.6777e-05
# Epoch 178/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0377 - accuracy: 0.9964 - val_loss: 0.5810 - val_accuracy: 0.8036 - lr: 1.6777e-05
# Epoch 179/1000
# 9/9 [==============================] - 1s 68ms/step - loss: 0.0379 - accuracy: 0.9929 - val_loss: 0.6056 - val_accuracy: 0.8036 - lr: 1.6777e-05
# Epoch 180/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0401 - accuracy: 0.9929 - val_loss: 0.5946 - val_accuracy: 0.8393 - lr: 1.3422e-05
# Epoch 181/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0353 - accuracy: 0.9964 - val_loss: 0.5766 - val_accuracy: 0.8393 - lr: 1.3422e-05
# Epoch 182/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0345 - accuracy: 0.9964 - val_loss: 0.5934 - val_accuracy: 0.8214 - lr: 1.3422e-05
# Epoch 183/1000
# 9/9 [==============================] - 1s 71ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.5878 - val_accuracy: 0.8214 - lr: 1.3422e-05
# Epoch 184/1000
# 9/9 [==============================] - 1s 79ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 0.6042 - val_accuracy: 0.8393 - lr: 1.3422e-05
# Epoch 185/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.0335 - accuracy: 0.9964 - val_loss: 0.6070 - val_accuracy: 0.8571 - lr: 1.3422e-05
# Epoch 186/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.6051 - val_accuracy: 0.8393 - lr: 1.3422e-05
# Epoch 187/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.5890 - val_accuracy: 0.8214 - lr: 1.3422e-05
# Epoch 188/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 0.0325 - accuracy: 0.9964 - val_loss: 0.6120 - val_accuracy: 0.8571 - lr: 1.3422e-05
# Epoch 189/1000
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.6172 - val_accuracy: 0.8571 - lr: 1.3422e-05
# Epoch 190/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.5970 - val_accuracy: 0.8393 - lr: 1.0737e-05
# Epoch 191/1000
# 9/9 [==============================] - 1s 65ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.6106 - val_accuracy: 0.8571 - lr: 1.0737e-05
# Epoch 192/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0272 - accuracy: 0.9964 - val_loss: 0.5843 - val_accuracy: 0.8571 - lr: 1.0737e-05
# Epoch 193/1000
# 9/9 [==============================] - 1s 65ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.5922 - val_accuracy: 0.8571 - lr: 1.0737e-05
# Epoch 194/1000
# 9/9 [==============================] - 1s 70ms/step - loss: 0.0275 - accuracy: 0.9964 - val_loss: 0.6029 - val_accuracy: 0.8571 - lr: 1.0737e-05
# Epoch 195/1000
# 9/9 [==============================] - 1s 73ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.5825 - val_accuracy: 0.8393 - lr: 1.0737e-05
# Epoch 196/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.5907 - val_accuracy: 0.8571 - lr: 1.0737e-05
# Epoch 197/1000
# 9/9 [==============================] - 1s 67ms/step - loss: 0.0260 - accuracy: 0.9964 - val_loss: 0.6036 - val_accuracy: 0.8571 - lr: 1.0737e-05
# Epoch 198/1000
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0232 - accuracy: 0.9964 - val_loss: 0.5806 - val_accuracy: 0.8571 - lr: 1.0737e-05
# Epoch 199/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.5913 - val_accuracy: 0.8571 - lr: 1.0737e-05

# %%
model.evaluate(X_test, y_test, return_dict=True)
# Out:
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6287 - accuracy: 0.7812
# {'loss': 0.6287082433700562, 'accuracy': 0.78125}

# %%
def plot_history(history, imagename=False):
    """
    Plotting training and validation learning curves.
    
    Args:
        history: model history with all the metric measures
    """
    fig, (ax1, ax2) = plt.subplots(2)
    
    fig.set_size_inches(18.5, 10.5)
    
    # Plot loss
    ax1.set_title('Loss')
    ax1.plot(history.history['loss'], label = 'train')
    ax1.plot(history.history['val_loss'], label = 'test')
    ax1.set_ylabel('Loss')
    
    # Determine upper bound of y-axis
    max_loss = max(history.history['loss'] + history.history['val_loss'])
    
    ax1.set_ylim([0, np.ceil(max_loss)])
    ax1.set_xlabel('Epoch')
    ax1.legend(['Train', 'Validation']) 
    
    # Plot accuracy
    ax2.set_title('Accuracy')
    ax2.plot(history.history['accuracy'],  label = 'train')
    ax2.plot(history.history['val_accuracy'], label = 'test')
    ax2.set_ylabel('Accuracy')
    ax2.set_ylim([0, 1])
    ax2.set_xlabel('Epoch')
    ax2.legend(['Train', 'Validation'])
    plt.tight_layout()
    if imagename:
        plt.savefig(imagename)
    plt.show()

plot_history(history)

# %%
model.save(r"C:\Users\wegar\CNN-LSTM Deadlift Classification\Saved Models\LSTM KPS\Sumo Classifier\LSTM Sumo Classifier.keras")

# %%
import pickle
with open(r"C:\Users\wegar\CNN-LSTM Deadlift Classification\Saved Models\LSTM KPS\Sumo Classifier\LSTM Sumo Classifier History.pkl", "wb") as f:
    pickle.dump(history.history, f)
